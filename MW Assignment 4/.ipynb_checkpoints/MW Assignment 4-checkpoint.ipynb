# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import IPython.display
import pandas

# %%
def createarray(name):   
    timearray = "time" + name
    timearray = []
    return timearray

# %%
def analyze(audiofilename,csvfilename,name):
    sig , sr = librosa.load(audiofilename,mono=True,sr=None)
    df = pandas.read_csv(csvfilename,header=None)
    times = df.loc[:,0]
    D = np.abs(librosa.stft(sig,n_fft=4096))
    plt.figure()
    ax1 = plt.subplot(2, 1, 1)
    librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), x_axis='time', y_axis='log')
    plt.title('Estimated from Sonic Visualiser')
    plt.subplot(2, 1, 2, sharex=ax1)
    plt.vlines(times, 0, 1, color='r', alpha=0.9, linestyle='--', label='Onsets')
    plt.axis('tight')
    plt.legend(frameon=True, framealpha=0.75)
    
    return sig, sr, times
# Out:
#   File "<ipython-input-15-5e17f8b56056>", line 4
#     times + "name" = df.loc[:,0]
#     ^
# SyntaxError: can't assign to operator

# %%
y, sr = librosa.load('kingsloop.wav')
samp = np.zeros(len(y))
sampLoc=librosa.time_to_samples(kingsloop.values, sr=sr)
samp[sampLoc]=1
IPython.display.Audio(data=samp, rate=sr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-357a7e48d9cf> in <module>()
#       1 y, sr = librosa.load('kingsloop.wav')
#       2 samp = np.zeros(len(y))
# ----> 3 sampLoc=librosa.time_to_samples(kingsloop.values, sr=sr)
#       4 samp[sampLoc]=1
#       5 IPython.display.Audio(data=samp, rate=sr)
#
# NameError: name 'kingsloop' is not defined

# %%
print(timeskingsloop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-5a23a1043d1d> in <module>()
# ----> 1 print(timeskingsloop)
#
# NameError: name 'timeskingsloop' is not defined

# %%
analyze('kingsloop.wav', 'kingsLoop_vamp_qm-vamp-plugins_qm-onsetdetector_onsets.csv','kingsloop')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-c0d2fdced15e> in <module>()
# ----> 1 analyze('kingsloop.wav', 'kingsLoop_vamp_qm-vamp-plugins_qm-onsetdetector_onsets.csv','kingsloop')
#
# <ipython-input-10-7c03179cdc28> in analyze(audiofilename, csvfilename, name)
#       9     plt.title('Estimated from Sonic Visualiser')
#      10     plt.subplot(2, 1, 2, sharex=ax1)
# ---> 11     plt.vlines(times, 0, 1, color='r', alpha=0.9, linestyle='--', label='Onsets')
#      12     plt.axis('tight')
#      13     plt.legend(frameon=True, framealpha=0.75)
#
# NameError: name 'times' is not defined

# %%
def readOnsetCSV(audiofilename,csvfilename):

    sig , sr = librosa.load(audiofilename,mono=True,sr=None)

    df = pandas.read_csv(csvfilename,header=None)
    times = df.loc[:,0]

    D = np.abs(librosa.stft(sig,n_fft=4096))
    plt.figure()
    ax1 = plt.subplot(2, 1, 1)
    librosa.display.specshow(librosa.amplitude_to_db(D, ref=np.max), x_axis='time', y_axis='log')
    plt.title('Estimated from Sonic Visualiser')
    plt.subplot(2, 1, 2, sharex=ax1)
    plt.vlines(times, 0, 1, color='r', alpha=0.9, linestyle='--', label='Onsets')
    plt.axis('tight')
    plt.legend(frameon=True, framealpha=0.75)
    
    return sig, sr, times
