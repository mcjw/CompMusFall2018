# %%
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt

# %%
file = 'r1.wav'
sig1 , sr1 = librosa.load(file,mono=True,sr=None)

# %%
length_s = sig.shape[0] / sr1
print(length_s)
# Out:
# 23.783378684807257

# %%
time=np.arange(0,sig.shape[0])/sr1

# %%
plt.plot(time,sig1)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('r1 Waveform')
# Out:
# Text(0.5,1,'r1 Waveform')

# %%
plt.plot(time,sig1)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('r0 Waveform')
plt.xlim(15,25)
plt.ylim(-.5,.5)
# Out:
# (-0.5, 0.5)

# %%
r1Spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig1)), ref=np.max)

# %%
librosa.display.specshow(r1Spec, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('R1: Linear-frequency power spectrogram')
# Out:
# Text(0.5,1,'R1: Linear-frequency power spectrogram')

# %%
librosa.display.specshow(r1Spec, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Violin: Log-frequency power spectrogram')
# Out:
# Text(0.5,1,'Violin: Log-frequency power spectrogram')

# %%
file2 = 'r2.wav'
sig2 , sr2 = librosa.load(file,mono=True,sr=None)

# %%
length_s2 = sig.shape[0] / sr2
print(length_s2)
# Out:
# 23.783378684807257

# %%
time2=np.arange(0,sig.shape[0])/sr2

# %%
plt.plot(time,sig2)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('r2 Waveform')
# Out:
# Text(0.5,1,'r2 Waveform')

# %%
plt.plot(time,sig2)
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.title('r2 Waveform')
plt.xlim(0,10)
plt.ylim(-.8,.8)
# Out:
# (-0.8, 0.8)

# %%
r2Spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig2)), ref=np.max)

# %%
librosa.display.specshow(r2Spec, y_axis='linear')
plt.colorbar(format='%+2.0f dB')
plt.title('R1: Linear-frequency power spectrogram')
# Out:
# Text(0.5,1,'R1: Linear-frequency power spectrogram')

# %%
librosa.display.specshow(r2Spec, y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Violin: Log-frequency power spectrogram')
# Out:
# Text(0.5,1,'Violin: Log-frequency power spectrogram')
